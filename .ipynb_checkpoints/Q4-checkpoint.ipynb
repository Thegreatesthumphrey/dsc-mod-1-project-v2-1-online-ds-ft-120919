# %% [markdown]
# # 4
# ## Exploring the significance of movie genre

# %% [markdown]
# ### Importing necessary libraries // Establish a connection to the database

# %%
from importlib import reload

import sqlite3
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt

import seaborn as sns

# %%
conn = sqlite3.connect("movies_db.sqlite")
cur = conn.cursor()

# %%
for row in cur.execute("SELECT name FROM sqlite_master WHERE type='table';"):
    print(row)
# Out:
# ('imdb_title_crew',)
# ('imdb_title_ratings',)
# ('imdb_title_principals',)
# ('rt_movie_info',)
# ('rt_reviews',)
# ('tmdb_movies',)
# ('tn_movie_budgets',)
# ('imdb_name_basics',)
# ('imdb_title_akas',)
# ('bom_movie_gross',)
# ('imdb_title_basics',)

# %% [markdown]
# ### Joining necessary tables

# %%
cur.execute('''SELECT *
               FROM imdb_title_basics
               JOIN tn_movie_budgets
               ON imdb_title_basics.original_title = tn_movie_budgets.movie
               JOIN tmdb_movies
               ON tn_movie_budgets.movie = tmdb_movies.original_title
            ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#       tconst                    primary_title  \
# 0  tt0249516                       Foodfight!
# 1  tt0326592                    The Overnight
# 2  tt0337692                      On the Road
# 3  tt0359950  The Secret Life of Walter Mitty
# 4  tt0365907      A Walk Among the Tombstones
#
#                     original_title  start_year  runtime_minutes  \
# 0                       Foodfight!        2012             91.0
# 1                    The Overnight        2010             88.0
# 2                      On the Road        2012            124.0
# 3  The Secret Life of Walter Mitty        2013            114.0
# 4      A Walk Among the Tombstones        2014            114.0
#
#                     genres  index  id         release_date  \
# 0  Action,Animation,Comedy   1325  26  2010-02-12 00:00:00
# 1                     None   5620  21  2012-07-12 00:00:00
# 2  Adventure,Drama,Romance   2316  17  2010-10-15 00:00:00
# 3   Adventure,Comedy,Drama    436  37  2010-05-15 00:00:00
# 4       Action,Crime,Drama   2066  67  2010-01-05 00:00:00
#
#                              movie  ...      id  original_language  \
# 0                       Foodfight!  ...  116977                 en
# 1                    The Overnight  ...  308024                 en
# 2                      On the Road  ...   83770                 en
# 3  The Secret Life of Walter Mitty  ...  116745                 en
# 4      A Walk Among the Tombstones  ...  169917                 en
#
#                     original_title  popularity         release_date  \
# 0                       Foodfight!       4.705  2013-05-07 00:00:00
# 1                    The Overnight       6.576  2015-06-19 00:00:00
# 2                      On the Road       8.919  2012-12-21 00:00:00
# 3  The Secret Life of Walter Mitty      10.743  2013-12-25 00:00:00
# 4      A Walk Among the Tombstones      19.373  2014-09-19 00:00:00
#
#                              title  vote_average  vote_count  release_day  \
# 0                       Foodfight!           2.1          46            1
# 1                    The Overnight           6.0         200            4
# 2                      On the Road           5.6         518            4
# 3  The Secret Life of Walter Mitty           7.1        4859            2
# 4      A Walk Among the Tombstones           6.3        1685            4
#
#   release_month
# 0             5
# 1             6
# 2            12
# 3            12
# 4             9
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (3797, 30)

# %% [markdown]
# ### Looking at the relationship between genre and worldwide gross

# %%
df['genres'] = df['genres'].map(lambda x: x.split(",") if x else x)

# %%
df.head()
# Out:
#       tconst                    primary_title  \
# 0  tt0249516                       Foodfight!
# 1  tt0326592                    The Overnight
# 2  tt0337692                      On the Road
# 3  tt0359950  The Secret Life of Walter Mitty
# 4  tt0365907      A Walk Among the Tombstones
#
#                     original_title  start_year  runtime_minutes  \
# 0                       Foodfight!        2012             91.0
# 1                    The Overnight        2010             88.0
# 2                      On the Road        2012            124.0
# 3  The Secret Life of Walter Mitty        2013            114.0
# 4      A Walk Among the Tombstones        2014            114.0
#
#                         genres  index  id         release_date  \
# 0  [Action, Animation, Comedy]   1325  26  2010-02-12 00:00:00
# 1                         None   5620  21  2012-07-12 00:00:00
# 2  [Adventure, Drama, Romance]   2316  17  2010-10-15 00:00:00
# 3   [Adventure, Comedy, Drama]    436  37  2010-05-15 00:00:00
# 4       [Action, Crime, Drama]   2066  67  2010-01-05 00:00:00
#
#                              movie  ...      id  original_language  \
# 0                       Foodfight!  ...  116977                 en
# 1                    The Overnight  ...  308024                 en
# 2                      On the Road  ...   83770                 en
# 3  The Secret Life of Walter Mitty  ...  116745                 en
# 4      A Walk Among the Tombstones  ...  169917                 en
#
#                     original_title  popularity         release_date  \
# 0                       Foodfight!       4.705  2013-05-07 00:00:00
# 1                    The Overnight       6.576  2015-06-19 00:00:00
# 2                      On the Road       8.919  2012-12-21 00:00:00
# 3  The Secret Life of Walter Mitty      10.743  2013-12-25 00:00:00
# 4      A Walk Among the Tombstones      19.373  2014-09-19 00:00:00
#
#                              title  vote_average  vote_count  release_day  \
# 0                       Foodfight!           2.1          46            1
# 1                    The Overnight           6.0         200            4
# 2                      On the Road           5.6         518            4
# 3  The Secret Life of Walter Mitty           7.1        4859            2
# 4      A Walk Among the Tombstones           6.3        1685            4
#
#   release_month
# 0             5
# 1             6
# 2            12
# 3            12
# 4             9
#
# [5 rows x 30 columns]

# %%
cur.execute('''SELECT *
               FROM imdb_title_basics
               JOIN tn_movie_budgets
               ON imdb_title_basics.original_title = tn_movie_budgets.movie
               JOIN tmdb_movies
               ON tn_movie_budgets.movie = tmdb_movies.original_title
               ORDER BY popularity DESC
               LIMIT 150
            ''')
df2 = pd.DataFrame(cur.fetchall())
df2.columns = [i[0] for i in cur.description]
df2.head()
# Out:
#       tconst                              primary_title  \
# 0  tt4154756                     Avengers: Infinity War
# 1  tt2911666                                  John Wick
# 2  tt2310332  The Hobbit: The Battle of the Five Armies
# 3  tt0848228                               The Avengers
# 4  tt0848228                               The Avengers
#
#                               original_title  start_year  runtime_minutes  \
# 0                     Avengers: Infinity War        2018            149.0
# 1                                  John Wick        2014            101.0
# 2  The Hobbit: The Battle of the Five Armies        2014            144.0
# 3                               The Avengers        2012            143.0
# 4                               The Avengers        2012            143.0
#
#                     genres  index  id         release_date  \
# 0  Action,Adventure,Sci-Fi      6   7  2009-12-18 00:00:00
# 1    Action,Crime,Thriller   1905   6  2010-10-23 00:00:00
# 2        Adventure,Fantasy     21  22  2010-06-23 00:00:00
# 3  Action,Adventure,Sci-Fi     26  27  1995-04-07 00:00:00
# 4  Action,Adventure,Sci-Fi    934  35  2010-09-10 00:00:00
#
#                                        movie  ...      id  original_language  \
# 0                     Avengers: Infinity War  ...  299536                 en
# 1                                  John Wick  ...  245891                 en
# 2  The Hobbit: The Battle of the Five Armies  ...  122917                 en
# 3                               The Avengers  ...   24428                 en
# 4                               The Avengers  ...   24428                 en
#
#                               original_title  popularity         release_date  \
# 0                     Avengers: Infinity War      80.773  2018-04-27 00:00:00
# 1                                  John Wick      78.123  2014-10-24 00:00:00
# 2  The Hobbit: The Battle of the Five Armies      53.783  2014-12-17 00:00:00
# 3                               The Avengers      50.289  2012-05-04 00:00:00
# 4                               The Avengers      50.289  2012-05-04 00:00:00
#
#                                        title  vote_average  vote_count  \
# 0                     Avengers: Infinity War           8.3       13948
# 1                                  John Wick           7.2       10081
# 2  The Hobbit: The Battle of the Five Armies           7.3        8392
# 3                               The Avengers           7.6       19673
# 4                               The Avengers           7.6       19673
#
#    release_day release_month
# 0            4             4
# 1            4            10
# 2            2            12
# 3            4             5
# 4            4             5
#
# [5 rows x 30 columns]

# %%
df2['genres'] = df2['genres'].map(lambda x: x.split(",") if x else x)

# %%
df2.head()
# Out:
#       tconst                              primary_title  \
# 0  tt4154756                     Avengers: Infinity War
# 1  tt2911666                                  John Wick
# 2  tt2310332  The Hobbit: The Battle of the Five Armies
# 3  tt0848228                               The Avengers
# 4  tt0848228                               The Avengers
#
#                               original_title  start_year  runtime_minutes  \
# 0                     Avengers: Infinity War        2018            149.0
# 1                                  John Wick        2014            101.0
# 2  The Hobbit: The Battle of the Five Armies        2014            144.0
# 3                               The Avengers        2012            143.0
# 4                               The Avengers        2012            143.0
#
#                         genres  index  id         release_date  \
# 0  [Action, Adventure, Sci-Fi]      6   7  2009-12-18 00:00:00
# 1    [Action, Crime, Thriller]   1905   6  2010-10-23 00:00:00
# 2         [Adventure, Fantasy]     21  22  2010-06-23 00:00:00
# 3  [Action, Adventure, Sci-Fi]     26  27  1995-04-07 00:00:00
# 4  [Action, Adventure, Sci-Fi]    934  35  2010-09-10 00:00:00
#
#                                        movie  ...      id  original_language  \
# 0                     Avengers: Infinity War  ...  299536                 en
# 1                                  John Wick  ...  245891                 en
# 2  The Hobbit: The Battle of the Five Armies  ...  122917                 en
# 3                               The Avengers  ...   24428                 en
# 4                               The Avengers  ...   24428                 en
#
#                               original_title  popularity         release_date  \
# 0                     Avengers: Infinity War      80.773  2018-04-27 00:00:00
# 1                                  John Wick      78.123  2014-10-24 00:00:00
# 2  The Hobbit: The Battle of the Five Armies      53.783  2014-12-17 00:00:00
# 3                               The Avengers      50.289  2012-05-04 00:00:00
# 4                               The Avengers      50.289  2012-05-04 00:00:00
#
#                                        title  vote_average  vote_count  \
# 0                     Avengers: Infinity War           8.3       13948
# 1                                  John Wick           7.2       10081
# 2  The Hobbit: The Battle of the Five Armies           7.3        8392
# 3                               The Avengers           7.6       19673
# 4                               The Avengers           7.6       19673
#
#    release_day release_month
# 0            4             4
# 1            4            10
# 2            2            12
# 3            4             5
# 4            4             5
#
# [5 rows x 30 columns]

# %%
all_genres =[]
none_counter = 0
for genre in df2['genres']:
    if genre == None:
        none_counter += 1
    else:
        all_genres += genre

# %%
all_genres
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Sci-Fi',
#  'Thriller',
#  'Thriller',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'History',
#  'Action',
#  'Adventure',
#  'History',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'Music',
#  'Action',
#  'Mystery',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'Action',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Mystery',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Documentary',
#  'Drama',
#  'Sport',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Romance',
#  'Action',
#  'Crime',
#  'Drama',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Documentary',
#  'Drama',
#  'Horror',
#  'Sci-Fi',
#  'Action',
#  'Drama',
#  'War',
#  'Musical',
#  'Musical',
#  'Comedy',
#  'Fantasy',
#  'Comedy',
#  'Fantasy',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Music',
#  'Music',
#  'Fantasy',
#  'Fantasy',
#  'Musical',
#  'Musical',
#  'Drama',
#  'Drama',
#  'Action',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Drama',
#  'Music',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'History',
#  'Adventure',
#  'Animation',
#  'Drama',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Crime',
#  'Drama',
#  'History',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Thriller',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Adventure',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Adventure',
#  'Animation',
#  'Comedy']

# %%
unique_genres = set(all_genres)

# %%
genre_count = {}
for genre in unique_genres:
    genre_count[genre] = all_genres.count(genre)

# %%
genre_count
# Out:
# {'Mystery': 8,
#  'War': 1,
#  'Adventure': 76,
#  'History': 4,
#  'Biography': 6,
#  'Drama': 43,
#  'Crime': 11,
#  'Music': 4,
#  'Documentary': 2,
#  'Sport': 3,
#  'Musical': 12,
#  'Horror': 6,
#  'Sci-Fi': 33,
#  'Action': 78,
#  'Thriller': 18,
#  'Comedy': 24,
#  'Fantasy': 37,
#  'Family': 18,
#  'Animation': 12,
#  'Romance': 1}

# %%
values = []
labels = []

for genre, count in genre_count.items():
    labels.append(genre)
    values.append(count)

# %%
plt.figure(figsize=(8, 5))
plt.barh(labels, values)
plt.title("Genre Counts\nFor Top 150\nProfitable Movies")
# Out:
# Text(0.5, 1.0, 'Genre Counts\nFor Top 150\nProfitable Movies')

# %% [markdown]
# As far as worldwide gross goes, the most popular genres by far are Adventure, Action, and Drama followed closely by Sci-Fi and Fantasy.

# %% [markdown]
# ### Looking at the relationship between genre and popularity

# %%
cur.execute('''SELECT *
               FROM imdb_title_basics
               JOIN tn_movie_budgets
               ON imdb_title_basics.original_title = tn_movie_budgets.movie
               JOIN tmdb_movies
               ON tn_movie_budgets.movie = tmdb_movies.original_title
               ORDER BY worldwide_gross DESC
               LIMIT 150
            ''')
df3 = pd.DataFrame(cur.fetchall())
df3.columns = [i[0] for i in cur.description]
df3.head()
# Out:
#       tconst            primary_title           original_title  start_year  \
# 0  tt4154756   Avengers: Infinity War   Avengers: Infinity War        2018
# 1  tt0369610           Jurassic World           Jurassic World        2015
# 2  tt0848228             The Avengers             The Avengers        2012
# 3  tt2395427  Avengers: Age of Ultron  Avengers: Age of Ultron        2015
# 4  tt1825683            Black Panther            Black Panther        2018
#
#    runtime_minutes                   genres  index  id         release_date  \
# 0            149.0  Action,Adventure,Sci-Fi      6   7  2009-12-18 00:00:00
# 1            124.0  Action,Adventure,Sci-Fi     33  34  2007-08-03 00:00:00
# 2            143.0  Action,Adventure,Sci-Fi     26  27  1995-04-07 00:00:00
# 3            141.0  Action,Adventure,Sci-Fi      3   4  1995-11-22 00:00:00
# 4            134.0  Action,Adventure,Sci-Fi     41  42  2010-08-13 00:00:00
#
#                      movie  ...      id  original_language  \
# 0   Avengers: Infinity War  ...  299536                 en
# 1           Jurassic World  ...  135397                 en
# 2             The Avengers  ...   24428                 en
# 3  Avengers: Age of Ultron  ...   99861                 en
# 4            Black Panther  ...   86841                 en
#
#             original_title  popularity         release_date  \
# 0   Avengers: Infinity War      80.773  2018-04-27 00:00:00
# 1           Jurassic World      20.709  2015-06-12 00:00:00
# 2             The Avengers      50.289  2012-05-04 00:00:00
# 3  Avengers: Age of Ultron      44.383  2015-05-01 00:00:00
# 4            Black Panther       2.058  2011-01-18 00:00:00
#
#                      title  vote_average  vote_count  release_day  \
# 0   Avengers: Infinity War           8.3       13948            4
# 1           Jurassic World           6.6       14056            4
# 2             The Avengers           7.6       19673            4
# 3  Avengers: Age of Ultron           7.3       13457            4
# 4            Black Panther           5.1          11            1
#
#   release_month
# 0             4
# 1             6
# 2             5
# 3             5
# 4             1
#
# [5 rows x 30 columns]

# %%
df3['genres'] = df3['genres'].map(lambda x: x.split(",") if x else x)
df3.head()
# Out:
#       tconst            primary_title           original_title  start_year  \
# 0  tt4154756   Avengers: Infinity War   Avengers: Infinity War        2018
# 1  tt0369610           Jurassic World           Jurassic World        2015
# 2  tt0848228             The Avengers             The Avengers        2012
# 3  tt2395427  Avengers: Age of Ultron  Avengers: Age of Ultron        2015
# 4  tt1825683            Black Panther            Black Panther        2018
#
#    runtime_minutes                       genres  index  id  \
# 0            149.0  [Action, Adventure, Sci-Fi]      6   7
# 1            124.0  [Action, Adventure, Sci-Fi]     33  34
# 2            143.0  [Action, Adventure, Sci-Fi]     26  27
# 3            141.0  [Action, Adventure, Sci-Fi]      3   4
# 4            134.0  [Action, Adventure, Sci-Fi]     41  42
#
#           release_date                    movie  ...      id  \
# 0  2009-12-18 00:00:00   Avengers: Infinity War  ...  299536
# 1  2007-08-03 00:00:00           Jurassic World  ...  135397
# 2  1995-04-07 00:00:00             The Avengers  ...   24428
# 3  1995-11-22 00:00:00  Avengers: Age of Ultron  ...   99861
# 4  2010-08-13 00:00:00            Black Panther  ...   86841
#
#    original_language           original_title  popularity  \
# 0                 en   Avengers: Infinity War      80.773
# 1                 en           Jurassic World      20.709
# 2                 en             The Avengers      50.289
# 3                 en  Avengers: Age of Ultron      44.383
# 4                 en            Black Panther       2.058
#
#           release_date                    title  vote_average  vote_count  \
# 0  2018-04-27 00:00:00   Avengers: Infinity War           8.3       13948
# 1  2015-06-12 00:00:00           Jurassic World           6.6       14056
# 2  2012-05-04 00:00:00             The Avengers           7.6       19673
# 3  2015-05-01 00:00:00  Avengers: Age of Ultron           7.3       13457
# 4  2011-01-18 00:00:00            Black Panther           5.1          11
#
#    release_day release_month
# 0            4             4
# 1            4             6
# 2            4             5
# 3            4             5
# 4            1             1
#
# [5 rows x 30 columns]

# %%
all_genres2 =[]
none_counter = 0
for genre in df3['genres']:
    if genre == None:
        none_counter += 1
    else:
        all_genres2 += genre

# %%
unique_genres2 = set(all_genres2)

# %%
genre_count2 = {}
for genre in unique_genres2:
    genre_count2[genre] = all_genres2.count(genre)

# %%
genre_count2
# Out:
# {'Mystery': 1,
#  'Sport': 4,
#  'Adventure': 96,
#  'Biography': 3,
#  'Drama': 23,
#  'Crime': 4,
#  'Music': 1,
#  'Documentary': 6,
#  'History': 2,
#  'Musical': 10,
#  'Horror': 4,
#  'Sci-Fi': 36,
#  'Action': 64,
#  'Comedy': 36,
#  'Family': 22,
#  'Fantasy': 32,
#  'Thriller': 15,
#  'Animation': 32,
#  'Romance': 1}

# %%
values2 = []
labels2 = []

for genre, count in genre_count2.items():
    labels2.append(genre)
    values2.append(count)

# %%
plt.figure(figsize=(8, 5))
plt.barh(labels2, values2)
plt.title("Genre Counts\nFor Top 150\nMost Popular Movies")
# Out:
# Text(0.5, 1.0, 'Genre Counts\nFor Top 150\nMost Popular Movies')

# %% [markdown]
# Again, Adventure and Action seem to be the most popular with Sci-Fi and Fantasy close behind. However, unlike the most profitable movies, Comedy and Animation also rank fairly high.
